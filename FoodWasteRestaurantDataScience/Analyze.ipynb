# %%
#open food wastage file
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('./food_wastage_data.csv')
df.head()
# Out:
#   Type of Food  Number of Guests Event Type  Quantity of Food  \
# 0         Meat               310  Corporate               450
# 1         Meat               400   Birthday               500
# 2   Vegetables               302   Birthday               371
# 3         Meat               491   Birthday               497
# 4         Meat               300  Corporate               400
#
#   Storage Conditions Purchase History  Seasonality Preparation Method  \
# 0       Refrigerated          Regular  All Seasons             Buffet
# 1   Room Temperature          Regular       Winter             Buffet
# 2       Refrigerated          Regular       Summer             Buffet
# 3       Refrigerated          Regular  All Seasons        Finger Food
# 4       Refrigerated          Regular       Winter        Finger Food
#
#   Geographical Location   Pricing  Wastage Food Amount
# 0                 Urban       Low                   25
# 1              Suburban      High                   40
# ...

# %%
#find and delete empty cells
df = df.dropna(how='all')
df.shape
#get the unique values for each column
df.nunique()
# Out:
# Type of Food              5
# Number of Guests         39
# Event Type                4
# Quantity of Food         30
# Storage Conditions        2
# Purchase History          2
# Seasonality               3
# Preparation Method        3
# Geographical Location     3
# Pricing                   3
# Wastage Food Amount      26
# dtype: int64

# %%
#bar chart to show relationship between price and Wastage Food Amount
plt.figure(figsize=(10,5))
sns.barplot(x='Pricing',y='Wastage Food Amount',data=df)
plt.xticks(rotation=90)
plt.show()

# %%
# Bin the Number of Guests into ranges
bins = [0, 100, 200, 300, 400, 500, 600]
labels = ['0-100', '101-200', '201-300', '301-400', '401-500', '501-600']
df['Number of Guests Range'] = pd.cut(df['Number of Guests'], bins=bins, labels=labels)

# Create a bar plot for Number of Guests Range vs. Food Wastage
plt.figure(figsize=(10, 6))
sns.barplot(x='Number of Guests Range', y='Wastage Food Amount', data=df)
plt.title('Average Food Wastage by Number of Guests Range')
plt.xlabel('Number of Guests Range')
plt.ylabel('Average Wastage Food Amount')
plt.xticks(rotation=45)
plt.show()
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)

# %%
# bar plot for Type of Food
plt.figure(figsize=(10, 6))
sns.barplot(x='Type of Food', y='Wastage Food Amount', data=df)
plt.xticks(rotation=45)
plt.title('Average Food Wastage by Type of Food')
plt.xlabel('Type of Food')
plt.ylabel('Average Wastage Food Amount')
plt.show()

# %%
# Create a bar plot for Event Type vs. Average Food Wastage
plt.figure(figsize=(10, 6))
sns.barplot(x='Event Type', y='Wastage Food Amount', data=df)
plt.title('Average Food Wastage by Event Type')
plt.xlabel('Event Type')
plt.ylabel('Average Wastage Food Amount')
plt.xticks(rotation=45)
plt.show()

# %%
# Create a box plot for Storage Conditions vs. Food Wastage
plt.figure(figsize=(10, 6))
sns.boxplot(x='Storage Conditions', y='Wastage Food Amount', data=df)
plt.title('Food Wastage Distribution by Storage Conditions')
plt.xlabel('Storage Conditions')
plt.ylabel('Wastage Food Amount')
plt.show()

# %%
# Select relevant numerical columns
numerical_columns = ['Number of Guests', 'Quantity of Food']

# Add more numerical columns to the list as needed

# Add 'Wastage Food Amount' to the columns for visualization
numerical_columns.append('Wastage Food Amount')

# Create the pair plot
sns.pairplot(df[numerical_columns])
plt.suptitle('Pair Plot of Numerical Variables vs. Food Wastage', y=1.02)
plt.show()
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# Create a histogram of Wastage Food Amount
plt.figure(figsize=(10, 6))
plt.hist(df['Wastage Food Amount'], bins=15, edgecolor='black')
plt.title('Distribution of Wastage Food Amount')
plt.xlabel('Wastage Food Amount')
plt.ylabel('Frequency')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Create a violin plot for Geographical Location vs. Food Wastage
plt.figure(figsize=(10, 6))
sns.violinplot(x='Geographical Location', y='Wastage Food Amount', data=df)
plt.title('Food Wastage Distribution by Geographical Location')
plt.xlabel('Geographical Location')
plt.ylabel('Wastage Food Amount')
plt.show()

# %%
# Select relevant numerical columns
numerical_columns = ['Number of Guests', 'Quantity of Food', 'Wastage Food Amount']

# Create the pair plot
sns.pairplot(df[numerical_columns])
plt.suptitle('Pair Plot of Number of Guests, Quantity of Food, and Wastage Food Amount', y=1.02)
plt.show()
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
from sklearn.preprocessing import LabelEncoder 

label_encoder = LabelEncoder()
categorical_columns = ['Type of Food', 'Event Type', 'Seasonality', 'Preparation Method', 'Geographical Location']
df['Storage Conditions'] = label_encoder.fit_transform(df['Storage Conditions'])
df['Purchase History'] = label_encoder.fit_transform(df['Purchase History'])
# One-hot encode categorical columns
df_encoded = pd.get_dummies(df, columns=categorical_columns)
# Ordinal encode Pricing column
pricing_mapping = {'Low': 1, 'Moderate': 2, 'High': 3}
df_encoded['Pricing'] = df_encoded['Pricing'].map(pricing_mapping)

df = df_encoded

df
# Out:
#       Number of Guests  Quantity of Food  Storage Conditions  \
# 0                  310               450                   0
# 1                  400               500                   1
# 2                  302               371                   0
# 3                  491               497                   0
# 4                  300               400                   0
# ...                ...               ...                 ...
# 1777               310               350                   1
# 1778               284               443                   1
# 1779               220               300                   1
# 1780               250               350                   1
# 1781               400               500                   1
#
#       Purchase History  Pricing  Wastage Food Amount Number of Guests Range  \
# 0                    1        1                   25                301-400
# 1                    1        3                   40                301-400
# ...

# %%
# Example correlation matrix heatmap
plt.figure(figsize=(20, 8))
sns.heatmap(df.corr(), annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 3
#       1 # Example correlation matrix heatmap
#       2 plt.figure(figsize=(20, 8))
# ----> 3 sns.heatmap(df.corr(), annot=True, cmap='coolwarm')
#       4 plt.title('Correlation Matrix')
#       5 plt.show()
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/core/frame.py:10704, in DataFrame.corr(self, method, min_periods, numeric_only)
#   10702 cols = data.columns
#   10703 idx = cols.copy()
# > 10704 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10706 if method == "pearson":
#   10707     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/core/frame.py:1889, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1887 if dtype is not None:
#    1888     dtype = np.dtype(dtype)
# ...
